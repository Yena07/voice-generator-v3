# %% [markdown]
# # CosyVoice3 클로닝 비교 (원본 vs 보호본)
#
# 이미 **학습된 체크포인트(`best.pt`)** 가 있다는 가정 하에, 임의의 wav 한 개에 대해
# (a) 원본, (b) 보호본 으로 각각 CosyVoice3 zero-shot 클로닝한 뒤
# 두 합성음이 원래 화자와 얼마나 닮았는지 CAM++ 유사도로 비교한다.
#
# - **원본으로 클론** → 원래 화자와 유사도 **높음** (클로닝 성공)
# - **보호본으로 클론** → 유사도 **크게 하락** 하면 방어 성공
#
# **실행 전 준비**
# 1. 상단 메뉴 **런타임 → 런타임 유형 변경 → T4 GPU**
# 2. Drive에 ① wav 데이터(`원천데이터`) ② 학습된 `best.pt` ③ `campplus.onnx` 가 있을 것
#
# > ⚠ CosyVoice 설치는 무겁다(5~10분). `requirements.txt` 설치 중 torch 재설치로
# > **런타임 재시작** 안내가 뜰 수 있다. 그러면 재시작 후 셀 1~4를 다시 실행하고 이어서 진행한다.

# %% [markdown]
# ## 1. Drive 마운트 + 코드/의존성 준비

# %%
from google.colab import drive
drive.mount('/content/drive')

import os, shutil
if os.path.isdir('/content/voice_generator'):
    shutil.rmtree('/content/voice_generator')
# !git clone https://github.com/Yena07/voice-generator-v3.git /content/voice_generator
# !pip install -q onnx onnx2torch soundfile

# %% [markdown]
# ## 2. 경로 설정
# 본인 Drive 구조에 맞게 **이 셀만** 수정한다.

# %%
import os, glob

CODE_DIR   = '/content/voice_generator'
CHECKPOINT = '/content/drive/MyDrive/voice_gen_ckpt/best.pt'         # ← 학습된 모델 경로(본인 Drive)
DATA_DIR   = '/content/drive/MyDrive/New_Sample/원천데이터'           # 라벨 대사 탐색용 (선택)

# 보호(=클로닝) 할 원본 wav 1개. 폴더를 주면 첫 wav 자동 선택.
INPUT_WAV  = DATA_DIR
if os.path.isdir(INPUT_WAV):
    INPUT_WAV = glob.glob(os.path.join(INPUT_WAV, '**', '*.wav'), recursive=True)[0]

# campplus.onnx: Drive에 있으면 쓰고, 없으면 자동 다운로드
CAMPPLUS = '/content/drive/MyDrive/voice_pgd/campplus.onnx'
if not os.path.isfile(CAMPPLUS):
    CAMPPLUS = '/content/campplus.onnx'
    if not os.path.isfile(CAMPPLUS) or os.path.getsize(CAMPPLUS) < 1_000_000:
        # !wget -q -O "{CAMPPLUS}" https://huggingface.co/model-scope/CosyVoice-300M/resolve/main/campplus.onnx

print('CAMPPLUS  :', CAMPPLUS)
print('CHECKPOINT:', CHECKPOINT)
print('INPUT_WAV :', INPUT_WAV)
assert os.path.isfile(CAMPPLUS),   f'campplus 준비 실패: {CAMPPLUS}'
assert os.path.isfile(CHECKPOINT), f'체크포인트 없음: {CHECKPOINT}  ← best.pt 경로를 본인 Drive에 맞게 수정'
assert os.path.isfile(INPUT_WAV),  f'입력 wav 없음: {INPUT_WAV}  ← DATA_DIR 또는 INPUT_WAV 경로 확인'

# %% [markdown]
# ## 3. 보호본 생성 (infer.py)
# 원본에 보호 noise를 입혀 `/content/protected.wav` 저장. 소리는 원본과 거의 같아야 정상.

# %%
# !python "{CODE_DIR}/infer.py" \
    --checkpoint "{CHECKPOINT}" \
    --input "{INPUT_WAV}" \
    --output "/content/protected.wav"

from IPython.display import Audio, display
print('원본');   display(Audio(INPUT_WAV))
print('보호본'); display(Audio('/content/protected.wav'))

# %% [markdown]
# ## 4. CosyVoice repo clone + 의존성 설치 (5~10분)
# `pip install -r requirements.txt` 를 한꺼번에 하면 ruamel.yaml/hyperpyyaml **버전 충돌로
# 전체 설치가 중단**되어 `ModuleNotFoundError: hyperpyyaml` 이 난다.
# → **한 줄씩** 설치해 충돌 줄만 건너뛰고 나머지는 모두 설치한다.

# %%
# %cd /content
import os, shutil, subprocess
# 폴더가 있어도 비어있을 수 있으므로 requirements.txt 존재로 판단 (깡통 폴더면 지우고 재clone)
if not os.path.isfile('/content/CosyVoice/requirements.txt'):
    if os.path.isdir('/content/CosyVoice'):
        shutil.rmtree('/content/CosyVoice')
    # !git clone --recursive https://github.com/FunAudioLLM/CosyVoice.git
# %cd /content/CosyVoice
# !git submodule update --init --recursive

# 한꺼번에 설치하면 ruamel.yaml/hyperpyyaml 충돌로 전체가 중단됨 → 한 줄씩 설치.
# 핵심 과학 스택(numpy/scipy/protobuf/onnxruntime)은 CosyVoice가 낮추면 ABI 충돌 → SKIP 후 따로 처리.
# openai-whisper도 옛 핀은 빌드 실패 → SKIP 후 --no-deps로 설치.
SKIP = {'torch', 'torchaudio', 'numpy', 'numba', 'numba-cuda', 'scipy', 'pandas',
        'matplotlib', 'protobuf', 'onnxruntime', 'openai-whisper'}
fails = []
for raw in open('requirements.txt'):
    line = raw.strip()
    if not line or line.startswith(('#', '-')):
        continue
    name = line.split(';')[0].split('==')[0].split('>=')[0].split('<')[0].split('>')[0].strip().lower()
    if name in SKIP:
        continue
    if subprocess.run(['pip', 'install', '-q', line]).returncode != 0:
        fails.append(line)
print('설치 실패한 줄 (대개 무시 가능):', fails)

# !pip install -q hyperpyyaml modelscope
# !pip install -q onnx onnx2torch soundfile   # 비교용 패키지 재확인

# transformers / numpy2 호환 정리:
# !pip uninstall -y torchao                                          # numpy 충돌 유발 → 제거
# !pip install --force-reinstall --no-deps "protobuf==5.29.5"        # transformers는 protobuf 5.26+ 필요
# !pip install -q -U onnxruntime                                     # 옛 onnxruntime은 numpy1용 → 최신으로
# !pip install -q --no-deps openai-whisper                           # CosyVoice frontend가 import (numba/numpy 안 건드림)
# !pip install -q tiktoken                                           # whisper 런타임 의존
# !pip show protobuf | grep Version
print('✅ 설치 완료. [런타임 다시 시작] 후 섹션 4는 건너뛰고 섹션 5부터 진행하세요.')

# %% [markdown]
# ## 5. CosyVoice3 모델 다운로드 (약 2GB)

# %%
from huggingface_hub import snapshot_download
COSY_DIR = '/content/CosyVoice/pretrained_models/Fun-CosyVoice3-0.5B'
snapshot_download('FunAudioLLM/Fun-CosyVoice3-0.5B-2512', local_dir=COSY_DIR)
print('downloaded to', COSY_DIR)

# %% [markdown]
# ## 6. 프롬프트 대사 준비 + CosyVoice3 로드
# zero-shot은 프롬프트 음성의 **대사(transcription)** 가 필요하다.
# 데이터의 라벨 JSON(`발화정보.stt`)에서 자동 추출하고, **못 찾으면 직접 입력**한다.
# (라벨을 Drive에 안 올렸다면 아래 `PROMPT_TEXT` 를 원본에서 들리는 대사로 직접 수정)

# %%
import os, glob, json

# (1) 프롬프트 대사: 라벨 JSON에서 자동 추출 시도
PROMPT_TEXT = ''
LABEL_ROOT = os.path.join(os.path.dirname(DATA_DIR), '라벨링데이터')
stem = os.path.splitext(os.path.basename(INPUT_WAV))[0]
hits = glob.glob(os.path.join(LABEL_ROOT, '**', stem + '.json'), recursive=True)
if hits:
    with open(hits[0], encoding='utf-8') as f:
        PROMPT_TEXT = json.load(f).get('발화정보', {}).get('stt', '')

# (2) 자동 추출 실패 시: 아래 줄의 따옴표 안에 원본 음성의 대사를 직접 입력
if not PROMPT_TEXT:
    PROMPT_TEXT = '요즘은 무선 청소기 안 쓰는 사람이 없더라'   # ← INPUT_WAV에서 들리는 대사로 교체
print('프롬프트 대사:', PROMPT_TEXT)

# (3) 합성할 목표 문장 (원하는 문장으로 바꿔도 됨)
TTS_TEXT = '안녕하세요. 이 음성은 음성 합성 모델로 만들어진 결과입니다.'

# (4) CosyVoice3 로드 (cwd와 무관하게 import되도록 repo 루트를 sys.path에 명시)
# %cd /content/CosyVoice
import sys, torchaudio
sys.path.insert(0, '/content/CosyVoice')
sys.path.insert(0, '/content/CosyVoice/third_party/Matcha-TTS')
assert os.path.isdir('/content/CosyVoice/cosyvoice'), \
    'CosyVoice 폴더가 없음 → 재시작으로 날아갔을 수 있음. 섹션 4(설치)부터 다시 실행하세요.'
from cosyvoice.cli.cosyvoice import AutoModel
cosyvoice = AutoModel(model_dir=COSY_DIR)
print('CosyVoice3 로드 완료, sample_rate =', cosyvoice.sample_rate)

# %% [markdown]
# ## 7. 원본 / 보호본으로 각각 클로닝

# %%
import torchaudio

def clone(prompt_wav, out_path):
    sys_prompt = 'You are a helpful assistant.<|endofprompt|>' + PROMPT_TEXT
    for j in cosyvoice.inference_zero_shot(TTS_TEXT, sys_prompt, prompt_wav, stream=False):
        torchaudio.save(out_path, j['tts_speech'], cosyvoice.sample_rate)
        break   # 첫 세그먼트만 사용
    return out_path

CLONE_ORIG = '/content/clone_from_original.wav'
CLONE_PROT = '/content/clone_from_protected.wav'

print('원본으로 클로닝...');  clone(INPUT_WAV,               CLONE_ORIG)
print('보호본으로 클로닝...'); clone('/content/protected.wav', CLONE_PROT)
print('완료')

# %% [markdown]
# ## 8. 결과 들어보기
# ②는 원래 화자처럼, ③은 화자가 뭉개지거나 다른 목소리로 들리면 방어 성공.

# %%
from IPython.display import Audio, display
print('① 원본(프롬프트 화자)');      display(Audio(INPUT_WAV))
print('② 원본으로 클론한 합성음');   display(Audio(CLONE_ORIG))
print('③ 보호본으로 클론한 합성음'); display(Audio(CLONE_PROT))

# %% [markdown]
# ## 9. 화자 유사도 수치 비교 (CAM++)
# 원래 화자(원본 wav)와 각 합성음의 CAM++ 코사인 유사도를 계산한다.
# 합성음은 CosyVoice sample_rate이므로 16kHz로 리샘플 후 임베딩을 뽑는다.

# %%
import sys, numpy as np, torch, soundfile as sf
from math import gcd
from scipy.signal import resample_poly

sys.path.insert(0, CODE_DIR)
from loss import campplus_embed_single, cosine_dist
import onnx, onnx2torch

dev = 'cuda' if torch.cuda.is_available() else 'cpu'
cam = onnx2torch.convert(onnx.load(CAMPPLUS)).eval().to(dev)
for p in cam.parameters():
    p.requires_grad = False

def emb16k(path):
    a, sr = sf.read(path, dtype='float32', always_2d=True)
    a = a.mean(axis=1).astype(np.float32)
    if sr != 16000:
        g = gcd(16000, sr); a = resample_poly(a, 16000 // g, sr // g).astype(np.float32)
    a = np.clip(a, -1.0, 1.0)
    t = torch.from_numpy(a).unsqueeze(0).to(dev)
    with torch.no_grad():
        return campplus_embed_single(cam, t)

ref = emb16k(INPUT_WAV)
sim_orig = 1.0 - cosine_dist(emb16k(CLONE_ORIG), ref).item()
sim_prot = 1.0 - cosine_dist(emb16k(CLONE_PROT), ref).item()
red = (sim_orig - sim_prot) / max(sim_orig, 1e-6) * 100

print('=' * 46)
print(' 원래 화자와의 CAM++ 유사도 (1에 가까울수록 동일 화자)')
print('=' * 46)
print(f'  ② 원본으로 클론   : {sim_orig:.4f}   (높을수록 클로닝 성공)')
print(f'  ③ 보호본으로 클론 : {sim_prot:.4f}   (낮을수록 방어 성공)')
print(f'  유사도 감소율     : {red:.1f}%')
print('-' * 46)
print('  ✅ 방어 효과 있음' if sim_prot < sim_orig - 0.1 else '  ⚠ 방어 효과 미미 — 더 학습 필요')
